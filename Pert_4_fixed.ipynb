# %%
# Importing the libraries
import pandas as pd
import pylab as pl
import numpy as np
import scipy.optimize as opt
import statsmodels.api as sm
from sklearn import preprocessing
import matplotlib.pyplot as plt
import matplotlib.mlab
import seaborn as sn

# %%
# Importing the dataset
dataset = pd.read_csv('CarPrice_Assignment.csv')
dataset.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
# 5        sedan        fwd          front       99.8  ...         136
# 6        sedan        fwd          front      105.8  ...         136
# 7        wagon        fwd          front      105.8  ...         136
# 8        sedan        fwd          front      105.8  ...         131
# 9    hatchback        4wd          front       99.5  ...         131
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
# 5        mpfi       3.19    3.40              8.5        110     5500      19
# 6        mpfi       3.19    3.40              8.5        110     5500      19
# 7        mpfi       3.19    3.40              8.5        110     5500      19
# 8        mpfi       3.13    3.40              8.3        140     5500      17
# 9        mpfi       3.13    3.40              7.0        160     5500      16
#
#    highwaympg      price
# 0          27  13495.000
# 1          27  16500.000
# 2          26  16500.000
# 3          30  13950.000
# 4          22  17450.000
# 5          25  15250.000
# 6          25  17710.000
# 7          25  18920.000
# 8          20  23875.000
# 9          22  17859.167
#
# [10 rows x 26 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
dataset.corrwith(dataset["price"])
# Out:
# <ipython-input-4-f82beb1abab2>:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corrwith(dataset["price"])
# car_ID             -0.109093
# symboling          -0.079978
# wheelbase           0.577816
# carlength           0.682920
# carwidth            0.759325
# carheight           0.119336
# curbweight          0.835305
# enginesize          0.874145
# boreratio           0.553173
# stroke              0.079443
# compressionratio    0.067984
# horsepower          0.808139
# peakrpm            -0.085267
# citympg            -0.685751
# highwaympg         -0.697599
# price               1.000000
# dtype: float64

# %%
dataset.corr().style.background_gradient().set_precision(2)
# Out:
# <ipython-input-5-3c224451b2b8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr().style.background_gradient().set_precision(2)
# <ipython-input-5-3c224451b2b8>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dataset.corr().style.background_gradient().set_precision(2)
# <style type="text/css">
# #T_992f5_row0_col0, #T_992f5_row1_col1, #T_992f5_row2_col2, #T_992f5_row3_col3, #T_992f5_row4_col4, #T_992f5_row5_col5, #T_992f5_row6_col6, #T_992f5_row7_col7, #T_992f5_row8_col8, #T_992f5_row9_col9, #T_992f5_row10_col10, #T_992f5_row11_col11, #T_992f5_row12_col12, #T_992f5_row13_col13, #T_992f5_row14_col14, #T_992f5_row15_col15 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_992f5_row0_col1, #T_992f5_row3_col9 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_992f5_row0_col2, #T_992f5_row0_col4, #T_992f5_row0_col11 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_992f5_row0_col3, #T_992f5_row9_col4, #T_992f5_row10_col2, #T_992f5_row10_col4 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_992f5_row0_col5, #T_992f5_row12_col11 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_992f5_row0_col6, #T_992f5_row1_col11, #T_992f5_row5_col15 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_992f5_row0_col7, #T_992f5_row5_col11, #T_992f5_row5_col14, #T_992f5_row8_col0 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_992f5_row0_col8, #T_992f5_row4_col5 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_992f5_row0_col9, #T_992f5_row1_col5, #T_992f5_row5_col1, #T_992f5_row6_col14, #T_992f5_row10_col12, #T_992f5_row11_col13, #T_992f5_row12_col0, #T_992f5_row12_col10, #T_992f5_row13_col8, #T_992f5_row13_col11, #T_992f5_row14_col2, #T_992f5_row14_col3, #T_992f5_row14_col4, #T_992f5_row14_col6, #T_992f5_row14_col7, #T_992f5_row14_col8, #T_992f5_row14_col15 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_992f5_row0_col10, #T_992f5_row6_col10 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_992f5_row0_col12, #T_992f5_row11_col10 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_992f5_row0_col13, #T_992f5_row9_col2 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_992f5_row0_col14, #T_992f5_row10_col15 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_992f5_row0_col15, #T_992f5_row9_col1 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_992f5_row1_col0, #T_992f5_row13_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_992f5_row1_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_992f5_row1_col3, #T_992f5_row6_col1, #T_992f5_row15_col9 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_992f5_row1_col4 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_992f5_row1_col6, #T_992f5_row13_col5 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_992f5_row1_col7 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_992f5_row1_col8 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_992f5_row1_col9 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_992f5_row1_col10, #T_992f5_row14_col0 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_992f5_row1_col12 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_992f5_row1_col13 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_992f5_row1_col14, #T_992f5_row8_col5 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_992f5_row1_col15 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_992f5_row2_col0, #T_992f5_row2_col9 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_992f5_row2_col1, #T_992f5_row13_col15 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_992f5_row2_col3, #T_992f5_row4_col6, #T_992f5_row6_col3, #T_992f5_row7_col15 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_992f5_row2_col4, #T_992f5_row2_col6 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_992f5_row2_col5, #T_992f5_row5_col2, #T_992f5_row11_col8 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_992f5_row2_col7 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_992f5_row2_col8 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_992f5_row2_col10, #T_992f5_row5_col8 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_992f5_row2_col11 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_992f5_row2_col12, #T_992f5_row3_col14, #T_992f5_row15_col14 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_992f5_row2_col13 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_992f5_row2_col14, #T_992f5_row7_col0, #T_992f5_row12_col5 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_992f5_row2_col15, #T_992f5_row3_col8, #T_992f5_row3_col11, #T_992f5_row8_col7 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_992f5_row3_col0 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_992f5_row3_col1, #T_992f5_row6_col12, #T_992f5_row8_col13, #T_992f5_row12_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_992f5_row3_col2, #T_992f5_row6_col4 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_992f5_row3_col4, #T_992f5_row6_col15 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_992f5_row3_col5, #T_992f5_row8_col2 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_992f5_row3_col6 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_992f5_row3_col7 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_992f5_row3_col10, #T_992f5_row12_col14 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_992f5_row3_col12, #T_992f5_row13_col9, #T_992f5_row14_col9 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_992f5_row3_col13 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_992f5_row3_col15, #T_992f5_row7_col3, #T_992f5_row15_col3 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_992f5_row4_col0, #T_992f5_row11_col9, #T_992f5_row12_col8 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_992f5_row4_col1 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_992f5_row4_col2 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_992f5_row4_col3, #T_992f5_row15_col6 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_992f5_row4_col7, #T_992f5_row7_col4 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_992f5_row4_col8, #T_992f5_row7_col2 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_992f5_row4_col9, #T_992f5_row10_col0, #T_992f5_row12_col6 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_992f5_row4_col10, #T_992f5_row15_col5 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_992f5_row4_col11 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_992f5_row4_col12 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_992f5_row4_col13, #T_992f5_row7_col13 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_992f5_row4_col14, #T_992f5_row7_col14 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_992f5_row4_col15, #T_992f5_row15_col4 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_992f5_row5_col0, #T_992f5_row12_col13 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_992f5_row5_col3 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_992f5_row5_col4 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_992f5_row5_col6 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_992f5_row5_col7 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_992f5_row5_col9, #T_992f5_row8_col9 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_992f5_row5_col10, #T_992f5_row14_col10 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_992f5_row5_col12, #T_992f5_row12_col9, #T_992f5_row15_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_992f5_row5_col13 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_992f5_row6_col0 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_992f5_row6_col2 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_992f5_row6_col5 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_992f5_row6_col7 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_992f5_row6_col8 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_992f5_row6_col9, #T_992f5_row7_col1, #T_992f5_row14_col5 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_992f5_row6_col11, #T_992f5_row11_col6 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_992f5_row6_col13 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_992f5_row7_col5, #T_992f5_row11_col1, #T_992f5_row11_col12 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_992f5_row7_col6 {
#   background-color: #034e7b;
#   color:

# %%
dataset.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
X = np.asarray(dataset[['wheelbase', 'carlength', 'carlength', 'carheight',
                           'curbweight', 'enginesize', 'boreratio', 'horsepower']])
y = np.asarray(dataset['price']) # label / target

# normalization of the dataset
X = preprocessing.StandardScaler().fit(X).transform(X)

# %%
# Train-and-Test -Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size = 0.3, random_state = 4)


print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (143, 8) (143,)
# Test set: (62, 8) (62,)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Training the Multiple Linear Regression model on the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
model = regressor.fit(X_train, y_train)

y_pred = model.predict(X_test)
print (y_pred)
# Out:
# [ 5918.91251492 21810.68981164 14252.71781605   825.05071348
#  10928.46337782 15215.00301782  5919.5272998   7477.94132492
#  21749.53740848  6954.7813066  17912.77626877 33016.36547127
#   7509.37102249 12578.4607257   6004.10102667 14735.3900224
#  12240.62071765 16398.13457375  9671.71485774  6265.15133546
#  11665.37695043 14691.87711024 11463.96608828 15346.14719625
#  22131.70838434  6196.08038975  6988.71047878 15808.04909278
#   7123.84407714  6231.93497981  9576.806617   11092.73674487
#  16940.60226083 11602.81269188  6415.53682962 27211.56478892
#  10080.8263711  17140.70636442  5613.90801595 36230.65887127
#   5872.95684823]

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [ 570.92505404 -135.91281985 -135.91281985  225.38167689 1946.21220395
#  3079.14927346 -387.82273877 2657.9316604 ]
# 13194.130189099078

# %%
score = model.score(X_test,y_test)*100
print('Accuracy of the model is = ', score)
# Out:
# Accuracy of the model is =  81.1856659114038

# %%
# accuracy for regression
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.811856659114038

# %%
harga = model.predict([[100,4,10,5,100,245,123,19]])
print('harga mobil =', harga)
# Out:
# harga mobil = [1021322.06157065]
